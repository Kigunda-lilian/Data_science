# %% [markdown]
# <a href="https://colab.research.google.com/github/Kigunda-lilian/Data_science/blob/main/lec3_notebook_answer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3 Practice and Comprehensive Questions Solutions

# %%
# The following libraries are used, so please load them beforehand
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series,DataFrame
import os
import zipfile
import requests
import io

# Visualization Library
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# Displayed to 3 decimal places
# %precision 3

# %%
## Loading the students-mat data
# Specify url with data
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00356/student.zip'

# Acquire data from url
r = requests.get(url, stream=True)

# Read and extract the zipfile
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %% [markdown]
# #### <Practice Question 3-1*>
#
# For the following data table, let's output data where `city` is Tokyo **or** `birth_year` is greater than 1990.

# %%
# Prepare data1
data1 = {
    'id': ['0', '1', '2', '3', '4', '6', '8', '11', '12', '13'],
    'city': ['Tokyo', 'Osaka', 'Kyoto', 'Hokkaido', 'Tokyo', 'Tokyo', 'Osaka', 'Kyoto', 'Hokkaido', 'Tokyo'],
    'birth_year': [1990, 1989, 1992, 1997, 1982, 1991, 1988, 1990, 1995, 1981],
    'name': ['Hiroshi', 'Akiko', 'Yuki', 'Satoru', 'Steeve', 'Mituru', 'Aoi', 'Tarou', 'Suguru', 'Mitsuo']
}
df1 = DataFrame(data1)
df1
# Out:
#    id      city  birth_year     name
# 0   0     Tokyo        1990  Hiroshi
# 1   1     Osaka        1989    Akiko
# 2   2     Kyoto        1992     Yuki
# 3   3  Hokkaido        1997   Satoru
# 4   4     Tokyo        1982   Steeve
# 5   6     Tokyo        1991   Mituru
# 6   8     Osaka        1988      Aoi
# 7  11     Kyoto        1990    Tarou
# 8  12  Hokkaido        1995   Suguru
# 9  13     Tokyo        1981   Mitsuo

# %%
df1[(df1['city']=='Tokyo') | (df1['birth_year']>1990)]
# Out:
#    id      city  birth_year     name
# 0   0     Tokyo        1990  Hiroshi
# 2   2     Kyoto        1992     Yuki
# 3   3  Hokkaido        1997   Satoru
# 4   4     Tokyo        1982   Steeve
# 5   6     Tokyo        1991   Mituru
# 8  12  Hokkaido        1995   Suguru
# 9  13     Tokyo        1981   Mitsuo

# %% [markdown]
# #### <Practice Question 3-2>
#
# Load the `student-mat.csv`. This dataset contains data of students' attributes and math scores in secondary education of two Portuguese schools.
#
# Columns `G1` and `G2` represent the students' math grade in the first and second period, respectively. Create a new column named `G1_G2_diff`, to calculate the change in grades from the first to the second period. Then, sort the dataset in **descending** order.

# %%
# Load the data
student_data_math = pd.read_csv('student-mat.csv', sep=';')

student_data_math["G1_G2_diff"] = student_data_math["G2"] - student_data_math["G1"]
student_data_math.sort_values("G1_G2_diff", ascending=False)

# %% [markdown]
# #### <Practice Question  3-3>
#
# Let's do an internal join between the following two data tables with the same `id` value.

# %%
# Prepare data 4
data4 = {
    'id':['0','1','2','3','4','6','8','11','12','13'],
    'city':['Tokyo','Osaka','Kyoto','Hokkaido','Tokyo','Tokyo','Osaka','Kyoto','Hokkaido','Tokyo'],
    'birth_year':[1990,1989,1992,1997,1982,1991,1988,1990,1995,1981],
    'name':['Hiroshi','Akiko','Yuki','Satoru','Steeve','Mituru','Aoi','Tarou','Suguru','Mitsuo']
}
df4 = DataFrame(data4)
print(df4)

# Prepare data 5
data5 = {
    'id':['0','1','3','6','8'],
    'math':[20,30,50,70,90],
    'English':[30,50,50,70,20],
    'sex':['M','F','F','M','M'],
    'index_num':[0,1,2,3,4]
}
df5 = DataFrame(data5)
print(df5)
# Out:
#    id      city  birth_year     name
# 0   0     Tokyo        1990  Hiroshi
# 1   1     Osaka        1989    Akiko
# 2   2     Kyoto        1992     Yuki
# 3   3  Hokkaido        1997   Satoru
# 4   4     Tokyo        1982   Steeve
# 5   6     Tokyo        1991   Mituru
# 6   8     Osaka        1988      Aoi
# 7  11     Kyoto        1990    Tarou
# 8  12  Hokkaido        1995   Suguru
# 9  13     Tokyo        1981   Mitsuo
#   id  math  English sex  index_num
# 0  0    20       30   M          0
# 1  1    30       50   F          1
# 2  3    50       50   F          2
# 3  6    70       70   M          3
# 4  8    90       20   M          4

# %%
# Answer
pd.merge(df4, df5, on='id')
# Out:
#   id      city  birth_year     name  math  English sex  index_num
# 0  0     Tokyo        1990  Hiroshi    20       30   M          0
# 1  1     Osaka        1989    Akiko    30       50   F          1
# 2  3  Hokkaido        1997   Satoru    50       50   F          2
# 3  6     Tokyo        1991   Mituru    70       70   M          3
# 4  8     Osaka        1988      Aoi    90       20   M          4

# %% [markdown]
# #### <Practice Question 3-4>
# Using the data from <Exercise 3-3>, let's vertically join the following data for `df4`.

# %%
# Preparing data
data6 = {
    'id':['70','80','90','120','150'],
    'city':['Chiba','Kanagawa','Tokyo','Fukuoka','Okinawa'],
    'birth_year':[1980,1999,1995,1994,1994],
    'name':['Suguru','Kouichi','Satochi','Yukie','Akari']
}
df6 = DataFrame(data6)

# %%
pd.concat([df4, df6])
# Out:
#     id      city  birth_year     name
# 0    0     Tokyo        1990  Hiroshi
# 1    1     Osaka        1989    Akiko
# 2    2     Kyoto        1992     Yuki
# 3    3  Hokkaido        1997   Satoru
# 4    4     Tokyo        1982   Steeve
# 5    6     Tokyo        1991   Mituru
# 6    8     Osaka        1988      Aoi
# 7   11     Kyoto        1990    Tarou
# 8   12  Hokkaido        1995   Suguru
# 9   13     Tokyo        1981   Mitsuo
# 0   70     Chiba        1980   Suguru
# 1   80  Kanagawa        1999  Kouichi
# 2   90     Tokyo        1995  Satochi
# 3  120   Fukuoka        1994    Yukie
# 4  150   Okinawa        1994    Akari

# %% [markdown]
# #### <Practice Question 3-5>
#
# For the following data, extract only the `Kyoto` column.

# %%
hier_df1 = DataFrame(
    np.arange(12).reshape((3,4)),
    index = [['c','d','d'], [1,2,1]],
    columns = [
        ['Kyoto','Nagoya','Hokkaido','Kyoto'],
        ['Yellow','Yellow','Red','Blue']
    ]
)

hier_df1.index.names = ['key1','key2']
hier_df1.columns.names = ['city','color']
hier_df1
# Out:
# city       Kyoto Nagoya Hokkaido Kyoto
# color     Yellow Yellow      Red  Blue
# key1 key2
# c    1         0      1        2     3
# d    2         4      5        6     7
#      1         8      9       10    11

# %%
# Answer
hier_df1['Kyoto']
# Out:
# color      Yellow  Blue
# key1 key2
# c    1          0     3
# d    2          4     7
#      1          8    11

# %% [markdown]
# #### <Practice Question 3-6>
# For the data in <Exercise 3-5>, summarize the `city` and give the average value between columns.

# %%
# Answer
# Sum of column 'city'
hier_df1.groupby(level='city', axis=1).mean()
# Out:
# <ipython-input-39-3e52e59a1e7d>:3: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   hier_df1.groupby(level= 'city', axis = 1).mean()
# city       Hokkaido  Kyoto  Nagoya
# key1 key2
# c    1          2.0    1.5     1.0
# d    2          6.0    5.5     5.0
#      1         10.0    9.5     9.0

# %% [markdown]
# #### <Exercise 3-7>
#
# For the data in <Exercise 3-5>, let's calculate the sum of the rows for each `key2`.

# %%
# Answer
# Sum of row 'key'
hier_df1.groupby(level='key2', axis=0).sum()
# Out:
# <ipython-input-40-1e562579c98b>:3: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   hier_df1.groupby(level= 'key2', axis = 0).sum()
# city   Kyoto Nagoya Hokkaido Kyoto
# color Yellow Yellow      Red  Blue
# key2
# 1          8     10       12    14
# 2          4      5        6     7

# %% [markdown]
# #### <Practice Question 3-8>
#
# Load the `student-mat.csv`, the dataset with students' attributes and math scores in secondary education of two Portuguese schools.
#
# Column `absences` represent the number of absences. Let's count the number of people in each of the following three bins in this column. Note that the default behavior of `cut` is a closed interval on the right side. This time, specify the option `right=False` for the `cut` function to make the right side the open interval.

# %%
# Granularity of division
absences_bins = [0, 1, 5, 100]

# %%
# Answer
student_data_math = pd.read_csv('student-mat.csv',sep=';')

student_data_math_ab_cut_data = pd.cut(student_data_math.absences,absences_bins,right=False)
pd.value_counts(student_data_math_ab_cut_data)
# Out:
# <ipython-input-44-be273fc3683b>:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(student_data_math_ab_cut_data)
# absences
# [5, 100)    151
# [1, 5)      129
# [0, 1)      115
# Name: count, dtype: int64

# %% [markdown]
# #### <Practice Question 3-9>
#
# With the same data as above, let's divide the “`absences`” column into three bins using the `qcut` function.

# %%
# Answer
student_data_math_ab_qcut_data = pd.qcut(student_data_math.absences,3)
pd.value_counts(student_data_math_ab_qcut_data)
# Out:
# <ipython-input-45-180a2f79e750>:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(student_data_math_ab_qcut_data)
# absences
# (-0.001, 2.0]    183
# (6.0, 75.0]      115
# (2.0, 6.0]        97
# Name: count, dtype: int64

# %% [markdown]
# #### <Practice Question 3-10>
#
# Let's use `student-mat.csv` to do the Pandas aggregation process.
#
# First, let's find the average score for each `G1` on the basis of school (`school`). Columns `G1` and `school` represent the students' math grade in the first period and the students' school, respectively.

# %%
student_data_math.groupby(['school'])['G1'].mean()
# Out:
# school
# GP    10.939828
# MS    10.673913
# Name: G1, dtype: float64

# %% [markdown]
# #### <Practice Question 3-11>
#
# Columns `G2` and `G3` represent the students' math grade in the second period and final grade, respectively. Column `address` represent where they live ('U' - urban or 'R' - rural).
#
# Let's use “student-mat.csv” to find the average score for columns `G1`, `G2`, and `G3`, respectively, grouped by school (`school`) and address (`address`).

# %%
# Answer
student_data_math.groupby(['school', 'address'])[['G1','G2','G3']].mean()
# Out:
#                    G1         G2         G3
# school sex
# GP     F    10.579235  10.398907   9.972678
#        M    11.337349  11.204819  11.060241
# MS     F    10.920000  10.320000   9.920000
#        M    10.380952  10.047619   9.761905

# %% [markdown]
# The reason why the results are different from those in <Exercise 3-10> above is that the answer to <Exercise 3-10> is a Series type and this time the answer is a DataFrame.

# %% [markdown]
# #### <Practice Question 3-12>
#
# Let's use “student-mat.csv” to calculate the maximum and minimum values of `G1`, `G2`, and `G3` together, based on school (`school`) and address (`address`).

# %%
# Answer
functions = ['max','min']
student_data_math2 = student_data_math.groupby(['school','address'])
student_data_math2[['G1','G2','G3']].agg(functions)
# Out:
#             G1      G2      G3
#            max min max min max min
# school sex
# GP     F    18   4  18   0  19   0
#        M    19   3  19   0  20   0
# MS     F    19   6  18   5  19   0
#        M    15   6  16   5  16   0

# %% [markdown]
# #### <Practice Question 3-13>
#
# For the following data, if there is even one column of `NaN`, delete it and display the result.

# %%
#@title
# Prepare data
import numpy as np
from numpy import nan as NA
import pandas as pd


df2 = pd.DataFrame(np.random.rand(15,6))

# Make it NA
df2.iloc[2,0] = NA
df2.iloc[5:8,2] = NA
df2.iloc[7:9,3] = NA
df2.iloc[10,5] = NA


df2
# Out:
#            0         1         2         3         4         5
df2.fillna(df2.mean())
# Out:
#            0         1         2         3         4         5
# 0   0.791769  0.638860  0.341616  0.348394  0.870068  0.147581
# 1   0.028736  0.803879  0.098832  0.667700  0.742869  0.643241
# 2   0.363764  0.746768  0.592508  0.490249  0.172411  0.983452
# 3   0.860476  0.197266  0.846536  0.904319  0.392409  0.184818
# 4   0.640391  0.432057  0.812705  0.214113  0.962842  0.952349
# 5   0.161999  0.662972  0.496265  0.267507  0.983222  0.226578
# 6   0.864094  0.174769  0.496265  0.352991  0.167277  0.455572
# 7   0.137875  0.636197  0.496265  0.467993  0.526493  0.326907
# 8   0.105027  0.214520  0.453157  0.467993  0.681381  0.201739
# 9   0.126898  0.640023  0.402511  0.212599  0.479169  0.661193
# 10  0.391543  0.831313  0.259475  0.620780  0.064709  0.532946
# 11  0.094735  0.586285  0.950620  0.250850  0.383542  0.625688
# 12  0.395400  0.569304  0.512944  0.617158  0.505209  0.807324
# 13  0.330168  0.476879  0.595822  0.422935  0.468440  0.544148
# 14  0.163583  0.784617  0.088454  0.714315  0.611128  0.700661

# %%
# For checking
df2.mean()
# Out:
# 0    0.363764
# 1    0.559714
# 2    0.496265
# 3    0.467993
# 4    0.534078
# 5    0.532946
# dtype: float64

# %% [markdown]
# ## 3.7 Comprehensive Question

# %% [markdown]
# ### Comprehensive Question 3-1 Data Manipulation
#
# Using the data `student-mat.csv', which is the data showing math scores, answer the following questions.
#
# (1) For the above data, calculate the average score of `G1` by age (`age`) x sex (`sex`) and create a table (table) such that the vertical axis is age (`age`) and the horizontal axis is sex (`sex`).
#
# (2) For the result table displayed in (1), delete all the rows (records) that are NaN.

# %%
# Answer
# (1)
student_data_math.groupby(['age','sex'])['G1'].mean().unstack()
# Out:
# sex          F          M
# age
# 15   10.052632  12.250000
# 16   10.203704  11.740000
# 17   11.103448  10.600000
# 18   10.883721  10.538462
# 19   10.642857   9.700000
# 20   15.000000  13.000000
# 21         NaN  10.000000
# 22         NaN   6.000000

# %%
# Answer
# (2)
student_data_math.groupby(['age','sex'])['G1'].mean().unstack().dropna()
# Out:
# sex          F          M
# age
# 15   10.052632  12.250000
# 16   10.203704  11.740000
# 17   11.103448  10.600000
# 18   10.883721  10.538462
# 19   10.642857   9.700000
# 20   15.000000  13.000000

# %% [markdown]
# # How to Load Data

# %%
# Specify url with data
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00320/student.zip'
# Specify data from url
r = requests.get(url, stream=True)
# Extract student-mat.csv in the zipfile to the data directory in the current directory
with zipfile.ZipFile(io.BytesIO(r.content)) as existing_zip:
    existing_zip.extract('student-mat.csv', 'data')
# Directory where csvfile exists
data_dir = './data'
path = os.path.join(data_dir, 'student-mat.csv')
student_data_math = pd.read_csv(path,sep=';')

# %% [markdown]
# ---

# %% [markdown]
# **Acknowledgement**: For the usage of dataset below
# https://archive.ics.uci.edu/ml/machine-learning-databases/00320/student.zip
#
# **References**: Dua, D. and Graff, C. (2019). UCI Machine Learning Repository [[http://archive.ics.uci.edu/ml](http://archive.ics.uci.edu/ml)]. Irvine, CA: University of California, School of Information and Computer Science.
#
# P. Cortez and A. Silva. Using Data Mining to Predict Secondary School Student Performance. In A. Brito and J. Teixeira Eds., Proceedings of 5th FUture BUsiness TEChnology Conference (FUBUTEC 2008) pp.5-12, Porto, Portugal, April, 2008, EUROSIS, ISBN 978-9077381-39-7.
# [http://www3.dsi.uminho.pt/pcortez/student.pdf](http://www3.dsi.uminho.pt/pcortez/student.pdf)
